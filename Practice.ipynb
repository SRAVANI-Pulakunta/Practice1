# %% [markdown]
# # DATA STRUCTURES
# Data structures->store and organise data -> inc efficiency.
# Common DS
#
#   1.Array-Fixed size
#
#          -Indexed
#          -Type->integer array
#               ->Floating array
#           -operations->Traverse O(N)
#                      ->Search
#                               Sorted-O(logN)
#                               unsorted-O(N)
#                      ->update
#                      *insertion and deletion is not possible
#           -Application->To bulid another DS ex:hash table,list,heaps vector matrix
#                       ->Sorting algo-quick,merge
#
#      Python Array-"https://www.tutorialspoint.com/python_data_structure/python_arrays.htm"

# %% [markdown]
#  # 1.Arrays
#
# b   -Represents signed integer of size 1 byte/td>
#
# B	-Represents unsigned integer of size 1 byte
#
# c	-Represents character of size 1 byte
#
# i	-Represents signed integer of size 2 bytes
#
# I	-Represents unsigned integer of size 2 bytes
#
# f	-Represents floating point of size 4 bytes
#
# d	-Represents floating point of size 8 bytes

# %%
9from array import *
a=array('i',[10,20,30,40,50])
for i in a:
    print(i)
# Out:
# 10
# 20
# 30
# 40
# 50

# %%
from array import *
a=array('i',[10,20,30,40,50])
a.insert(3,25)
print("insert\n")
for i in a:
    print(i)
print("delete\n")
a.remove(30)
for i in a:
    print(i)
print("update\n")
a[2]=99
for i in a:
    print(i)
# Out:
# insert
#
# 10
# 20
# 30
# 25
# 40
# 50
# delete
#
# 10
# 20
# 25
# 40
# 50
# update
#
# 10
# 20
# 99
# 40
# 50

# %% [markdown]
# # 1.2.SORTING

# %% [markdown]
# QUICK SORT
#
#     Time complexity->Best:O(nlogn)
#                    ->Worst:O(n^2)
#    ![image.png](attachment:image.png)

# %%
def partition(arr,low,high): 
    i = ( low-1 )         # index of smaller element 
    pivot = arr[high]     # pivot 
  
    for j in range(low , high): 
  
        # If current element is smaller than the pivot 
        if   arr[j] < pivot: 
          
            # increment index of smaller element 
            i = i+1 
            arr[i],arr[j] = arr[j],arr[i] 
  
    arr[i+1],arr[high] = arr[high],arr[i+1] 
    return ( i+1 ) 

def quickSort(arr,low,high): 
    if low < high: 
  
        pi = partition(arr,low,high) 
        quickSort(arr, low, pi-1) 
        quickSort(arr, pi+1, high) 
  

arr = [10, 7, 8, 9, 1, 5] 
n = len(arr) 
quickSort(arr,0,n-1) 
print ("Sorted array is:") 
for i in range(n): 
    print ("%d" %arr[i]),
# Out:
# Sorted array is:
# 1
# 5
# 7
# 8
# 9
# 10

# %% [markdown]
# Merge Sort
#
#     Time complexity->Best:Ω(n log(n))
#                ->Worst:O(n log(n))
#  ![image.png](attachment:image.png)

# %%
# Python program for implementation of MergeSort 
def mergeSort(arr): 
    if len(arr) >1: 
        mid = len(arr)//2 #Finding the mid of the array 
        L = arr[:mid] # Dividing the array elements  
        R = arr[mid:] # into 2 halves 
  
        mergeSort(L) # Sorting the first half 
        mergeSort(R) # Sorting the second half 
  
        i = j = k = 0
          
        # Copy data to temp arrays L[] and R[] 
        while i < len(L) and j < len(R): 
            if L[i] < R[j]: 
                arr[k] = L[i] 
                i+=1
            else: 
                arr[k] = R[j] 
                j+=1
            k+=1
          
        # Checking if any element was left 
        while i < len(L): 
            arr[k] = L[i] 
            i+=1
            k+=1
          
        while j < len(R): 
            arr[k] = R[j] 
            j+=1
            k+=1
  
# Code to print the list 
def printList(arr): 
    for i in range(len(arr)):         
        print(arr[i],end=" ") 
    print() 
  
# driver code to test the above code 
if __name__ == '__main__': 
    arr = [12, 11, 13, 5, 6, 7]  
    print ("Given array is", end="\n")  
    printList(arr) 
    mergeSort(arr) 
    print("Sorted array is: ", end="\n") 
    printList(arr)
# Out:
# Given array is
# 12 11 13 5 6 7
# Sorted array is:
# 5 6 7 11 12 13

# %% [markdown]
# # 2.LINKED LIST
#
#     It's a sequential DS
#         -each node is linked to another node.
#         -Element:Node and Key:pointer(links to next node)
#         -Head-1st node Tail:last node
#     TYPES:-1.Singly Linked list:Travesal->one side   TC-O(n)
#            2.Doubly Linked list:Traversal->both side TC-O(n)
#            3.Circular Linked List:Traversal->Both sides and Last node key points to Head node
#     OPERATIONS:-1.Search- TC->O(n) ->both singly and doubly inked list
#                 2.Insert- TC->O(n)->both
#                 3.Deletion-TC->O(n)->both
#     APPLICATION:-1.Symbol table management
#                  2.To switch programs(Alt+Tab) i.e. circular linked list

# %%
#SINGLE LINK LIST
class Node: 
  
    def __init__(self, data): 
        self.data = data 
        self.next = None   
class LinkedList: 
    def __init__(self): 
        self.head = None
    def printList(self): 
        temp = self.head 
        while (temp): 
            print(temp.data) 
            temp = temp.next
if __name__=='__main__': 
   
    llist = LinkedList() 
  
    llist.head = Node(1) 
    second = Node(2) 
    third = Node(3) 
    llist.head.next = second; 

    second.next = third;  
    llist.printList()
# Out:
# 1
# 2
# 3

# %% [markdown]
# DOUBLY LINKED LIST
#
#     change
#         class Node:
#     def __init__(self, next=None, prev=None, data=None):
#         self.next = next
#         self.prev = prev
#         self.data = data

# %% [markdown]
# CIRCULAR LINKED LIST
#
#     def __init__(self):
#         self.head = None
#     def push(self, data):
#         ptr1 = Node(data)
#         temp = self.head
#
#         ptr1.next = self.head
#         if self.head is not None:
#             while(temp.next != self.head):
#                 temp = temp.next
#             temp.next = ptr1
#
#         else:
#             ptr1.next = ptr1 # For the first node
#
#         self.head = ptr1

# %% [markdown]
# # 3.STACK
#
#     -LIFO->Last In First Out
#     -Operation-push
#               -pop
#               -peek-return the top of the element
#               -isEmpty
#               -isFull
#     -Application-Parsing
#                 -Mathematical expression
#                 -implementing function call
#
#     -Time Complexity for every operation is O(1)

# %%
stack = [] 
stack.append('a') 
stack.append('b') 
stack.append('c') 
  
print('Initial stack') 
print(stack) 
print('\nElements poped from stack:') 
print(stack.pop()) 
print(stack.pop()) 
print(stack.pop()) 
  
print('\nStack after elements are poped:') 
print(stack)
# Out:
# Initial stack
# ['a', 'b', 'c']
#
# Elements poped from stack:
# c
# b
# a
#
# Stack after elements are poped:
# []

# %% [markdown]
# # 4.QUEUE
#
#     Time Complexicity-O(n)
#     FIFO->First In First Out
#     OPERATIONS->Enqueue
#               ->Dequeue
#     APPLICATIONS->multithreading
#                 ->priority queue

# %%
queue = []  
queue.append('a') 
queue.append('b') 
queue.append('c') 
  
print("Initial queue") 
print(queue)  
print("\nElements dequeued from queue") 
print(queue.pop(0)) 
print(queue.pop(0)) 
print(queue.pop(0)) 
  
print("\nQueue after removing elements") 
print(queue)
# Out:
# Initial queue
# ['a', 'b', 'c']
#
# Elements dequeued from queue
# a
# b
# c
#
# Queue after removing elements
# []

# %% [markdown]
# # 5.HASH TABLE
#
#     -Contains values and respective keys
#     -To avoid direct addressing(one-to-one) Hash table is used
#     -hash()-> is a built-in function that returns the hash value of an object ( if it has one ). Hash values are integer used to quickly compare dictionary keys while looking up a dictionary.
#
#     h(k) = k % m
#     h: Hash function
#     k: Key of which the hash value should be determined
#     m: Size of the hash table (number of slots available).
#
#  ![image.png](attachment:image.png)
#
#      APPLICATION->1.Use to implement database
#                 ->2.Used to implement associative arrays.
#                 ->3.Used to implement the “set” data structure.

# %%
dict = {'Name': 'Zara', 'Age': 7, 'Class': 'First'}

print ("dict['Name']: ", dict['Name'])
print ("dict['Age']: ", dict['Age'])
dict['Age'] = 8;
print("dict['age']",dict['Age'])
dict.clear();  
del dict ;
# Out:
# dict['Name']:  Zara
# dict['Age']:  7
# dict['age'] 8

# %% [markdown]
# # 6.TREES
#
#     -Hierarichical DS
#     -Traversal-inorder(L-Ro-R)
#               -preorder(Ro-L-R)
#               -postorder(L-R-Ro)
#     -TYPES-binary search tree, B tree, treap, red-black tree, splay tree, AVL tree and n-ary tree.

# %%
#Binary Search Tree(insert)
class Node: 
    def __init__(self,key): 
        self.left = None
        self.right = None
        self.val = key 

def insert(root,node): 
    if root is None: 
        root = node 
    else: 
        if root.val < node.val: 
            if root.right is None: 
                root.right = node 
            else: 
                insert(root.right, node) 
        else: 
            if root.left is None: 
                root.left = node 
            else: 
                insert(root.left, node) 

def inorder(root): 
    if root: 
        inorder(root.left) 
        print(root.val) 
        inorder(root.right) 
r = Node(50) 
insert(r,Node(30)) 
insert(r,Node(20)) 
insert(r,Node(40)) 
insert(r,Node(70)) 
insert(r,Node(60)) 
insert(r,Node(80)) 
inorder(r)
# Out:
# 20
# 30
# 40
# 50
# 60
# 70
# 80

# %%
#BTS(search)
def search(root,key):  
    if root is None or root.val == key: 
        return root 
    if root.val < key: 
        return search(root.right,key) 
    return search(root.left,key)

# %% [markdown]
# # 7.HEAP
#
#     -Special case of binary tree->values of parent and children are compared and arranged accordingly
#   ![image.png](attachment:image.png)
#   ![image.png](attachment:image.png)
#
#     -Types->min heap
#           ->max heap
#
#     -Application-Find Kth largest element in an array
#                 -Queue function with O(logN)

# %% [markdown]
# # 8.GRAPH
#
#     -finite set of vertices or nodes and a set of edges connecting these vertices
#     -Types->Directed
#           ->Undirected
#
#   ![image.png](attachment:image.png)

# %%
#function for generating graph
from collections import defaultdict 
  
# function for adding edge to graph 
graph = defaultdict(list) 
def addEdge(graph,u,v): 
    graph[u].append(v) 
def generate_edges(graph): 
    edges = [] 
    for node in graph: 
        for neighbour in graph[node]:  
            edges.append((node, neighbour)) 
    return edges 
addEdge(graph,'a','c') 
addEdge(graph,'b','c') 
addEdge(graph,'b','e') 
addEdge(graph,'c','d') 
addEdge(graph,'c','e') 
addEdge(graph,'c','a') 
addEdge(graph,'c','b') 
addEdge(graph,'e','b') 
addEdge(graph,'d','c')  
print(generate_edges(graph))
# Out:
# [('a', 'c'), ('b', 'c'), ('b', 'e'), ('c', 'd'), ('c', 'e'), ('c', 'a'), ('c', 'b'), ('e', 'b'), ('d', 'c')]
